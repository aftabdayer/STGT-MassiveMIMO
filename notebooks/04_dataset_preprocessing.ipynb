# %%
import h5py
import numpy as np
import torch
import torch.nn as nn
from torch.optim import Adam
from collections import OrderedDict
from tqdm import tqdm
import matplotlib.pyplot as plt

# === CONFIG ===
filename = 'H_32x72_120Kmph.mat'
output_npy = 'CSI_Comp_256_paper.npy'
encoded_dim = 256
epochs = 100
batch_size = 200
learning_rate = 1e-3

with h5py.File(filename, 'r') as f:
    HMat = f['HMat']
    N = HMat.shape[0]
    target_sc = 32    # downsample subcarriers
    target_ant = 32   # downsample antennas

    print("Processing samples...")
    all_csi = np.zeros((N, 2, target_sc, target_ant), dtype=np.float32)

    for i in tqdm(range(N)):
        arr = np.array(f[HMat[i, 0]])
        # real/imag shape: (n_sub, n_ant) or (n_sub, 1, n_ant) or (n_sub, n_ant, 1)
        real = arr['real']
        imag = arr['imag']
        
        # Squeeze extra dimensions if present
        real = np.squeeze(real)
        imag = np.squeeze(imag)
        # After squeeze, real shape = (n_sub, n_ant)

        n_subcarriers_actual, n_antenna_actual = real.shape
        # Pad/cut subcarriers to 256
        n_subcarriers = 256
        if n_subcarriers_actual < n_subcarriers:
            real_pad = np.zeros((n_subcarriers, n_antenna_actual), dtype=real.dtype)
            imag_pad = np.zeros((n_subcarriers, n_antenna_actual), dtype=imag.dtype)
            real_pad[:n_subcarriers_actual, :] = real
            imag_pad[:n_subcarriers_actual, :] = imag
            real = real_pad
            imag = imag_pad
        elif n_subcarriers_actual > n_subcarriers:
            real = real[:n_subcarriers, :]
            imag = imag[:n_subcarriers, :]
        # Now real/imag is (256, n_antenna_actual)

        # Downsample subcarriers to 32
        pool_factor_sc = n_subcarriers // target_sc
        real_sc = real[:target_sc * pool_factor_sc].reshape(target_sc, pool_factor_sc, n_antenna_actual).mean(axis=1)
        imag_sc = imag[:target_sc * pool_factor_sc].reshape(target_sc, pool_factor_sc, n_antenna_actual).mean(axis=1)

        # Downsample/pad antennas to 32
        if n_antenna_actual < target_ant:
            real_img = np.zeros((target_sc, target_ant), dtype=np.float32)
            imag_img = np.zeros((target_sc, target_ant), dtype=np.float32)
            real_img[:, :n_antenna_actual] = real_sc
            imag_img[:, :n_antenna_actual] = imag_sc
        elif n_antenna_actual == target_ant:
            real_img = real_sc
            imag_img = imag_sc
        else:
            pool_factor_ant = n_antenna_actual // target_ant
            real_img = real_sc[:, :target_ant * pool_factor_ant].reshape(target_sc, target_ant, pool_factor_ant).mean(axis=2)
            imag_img = imag_sc[:, :target_ant * pool_factor_ant].reshape(target_sc, target_ant, pool_factor_ant).mean(axis=2)
        
        all_csi[i, 0] = real_img
        all_csi[i, 1] = imag_img

print("All CSI array shape:", all_csi.shape)  # [N, 2, 32, 32]

# ---- The rest of your encoder/decoder training code goes below this unchanged ----


# ===========================
# STEP 2: Encoder/Decoder from Paper (from compare.py)
# ===========================
img_size = 32
img_height = 32
img_width = 32
img_channels = 2
img_total = img_height * img_width * img_channels
num_heads = 4
depth = 1
qkv_bias = True
window = 8
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class GroupAttention(nn.Module):
    def __init__(self, num_heads=4, qkv_bias=False):
        super().__init__()
        self.num_heads = num_heads
        head_dim = img_width // num_heads
        self.scale = head_dim ** -0.5
        self.qkv = nn.Linear(img_width, img_width * 3, bias=qkv_bias)
        self.proj = nn.Linear(img_width, img_width)
        self.ws = window
    def forward(self, x):
        B, C, H, W = x.shape
        h_group, w_group = H // self.ws, W // self.ws
        total_groups = h_group * w_group
        x = x.reshape(B, C, h_group, self.ws, W)
        qkv = self.qkv(x).reshape(B, C, total_groups, -1, 3, self.num_heads, self.ws // self.num_heads).permute(4, 0, 1, 2, 5, 3, 6)
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = (attn @ v).transpose(2, 3).reshape(B, h_group, w_group, self.ws, self.ws, C)
        x = attn.transpose(2, 3).reshape(B, C, H, W)
        x = self.proj(x)
        return x

class GlobalAttention(nn.Module):
    def __init__(self, num_heads=4, qkv_bias=False):
        super().__init__()
        self.dim = img_width
        self.num_heads = num_heads
        head_dim = self.dim // num_heads
        self.scale = head_dim ** -0.5
        self.q = nn.Linear(self.dim, self.dim, bias=qkv_bias)
        self.kv = nn.Linear(self.dim//window, self.dim//window * 2, bias=qkv_bias)
        self.proj = nn.Linear(self.dim, self.dim)
        self.sr = nn.Conv2d(2, 2, kernel_size=window, stride=window)
        self.norm = nn.LayerNorm(self.dim//window)
    def forward(self, x):
        B, C, H, W = x.shape
        q = self.q(x).reshape(B, C, -1, self.dim//window, self.dim//window).permute(0,1,3,2,4)
        x_ = self.sr(x).reshape(B, C, -1, self.dim//window, self.dim//window)
        x_ = self.norm(x_)
        kv = self.kv(x_).reshape(B, C, -1, 2, self.dim//window, self.dim//window).permute(3,0,1,4,2,5)
        k, v = kv[0], kv[1]
        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        x = (attn @ v).transpose(1, 2).reshape(B, C, H, W)
        x = self.proj(x)
        return x

class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.cc1 = nn.Linear(img_width, img_width)
        self.cc2 = nn.Linear(img_width, img_width)
        self.act = nn.GELU()
    def forward(self, x):
        x = self.cc1(x)
        x = self.act(x)
        x = self.cc2(x)
        return x

class WTL(nn.Module):
    def __init__(self, num_heads, qkv_bias):
        super().__init__()
        self.norm1 = nn.LayerNorm(img_width, eps=1e-6)
        self.attn1 = GroupAttention(num_heads=num_heads, qkv_bias=qkv_bias)
        self.attn2 = GlobalAttention(num_heads=num_heads, qkv_bias=qkv_bias)
        self.norm2 = nn.LayerNorm(img_width, eps=1e-6)
        self.norm3 = nn.LayerNorm(img_width, eps=1e-6)
        self.norm4 = nn.LayerNorm(img_width, eps=1e-6)
        self.mlp1 = MLP()
        self.mlp2 = MLP()
    def forward(self, x):
        x = x + self.attn1(self.norm1(x))
        x = x + self.mlp1(self.norm2(x))
        x = x + self.attn2(self.norm3(x))
        x = x + self.mlp2(self.norm4(x))
        return x

class ConvBN(nn.Sequential):
    def __init__(self, in_planes, out_planes, kernel_size, stride=1, groups=1):
        if not isinstance(kernel_size, int):
            padding = [(i - 1) // 2 for i in kernel_size]
        else:
            padding = (kernel_size - 1) // 2
        super().__init__(OrderedDict([
            ('conv', nn.Conv2d(in_planes, out_planes, kernel_size, stride, padding=padding, groups=groups, bias=False)),
            ('bn', nn.BatchNorm2d(out_planes))
        ]))

class CRBlock(nn.Module):
    def __init__(self):
        super().__init__()
        self.path1 = nn.Sequential(OrderedDict([
            ('conv3x3', ConvBN(2, 7, 3)),
            ('relu1', nn.LeakyReLU(negative_slope=0.3, inplace=True)),
            ('conv1x9', ConvBN(7, 7, [1, 9])),
            ('relu2', nn.LeakyReLU(negative_slope=0.3, inplace=True)),
            ('conv9x1', ConvBN(7, 7, [9, 1])),
        ]))
        self.path2 = nn.Sequential(OrderedDict([
            ('conv1x5', ConvBN(2, 7, [1, 5])),
            ('relu', nn.LeakyReLU(negative_slope=0.3, inplace=True)),
            ('conv5x1', ConvBN(7, 7, [5, 1])),
        ]))
        self.conv1x1 = ConvBN(7 * 2, 2, 1)
        self.identity = nn.Identity()
        self.relu = nn.LeakyReLU(negative_slope=0.3, inplace=True)
    def forward(self, x):
        identity = self.identity(x)
        out1 = self.path1(x)
        out2 = self.path2(x)
        out = torch.cat((out1, out2), dim=1)
        out = self.relu(out)
        out = self.conv1x1(out)
        out = self.relu(out + identity)
        return out

class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.blocks = nn.ModuleList([WTL(num_heads=num_heads, qkv_bias=True) for _ in range(depth)])
        self.norm2 = nn.LayerNorm(img_width, eps=1e-6)
        self.norm3 = nn.LayerNorm(img_width, eps=1e-6)
        self.conv1 = nn.Conv2d(2, 16, kernel_size=1, stride=1)
        self.conv5 = nn.Conv2d(16, 2, kernel_size=5, stride=1, padding=2)
        self.conv4 = nn.Conv2d(2, 2, kernel_size=4, stride=2, padding=1)
        self.convT = nn.ConvTranspose2d(2, 2, kernel_size=4, stride=2, padding=1)
        self.fc = nn.Linear(2*img_width*img_height, encoded_dim)
    def forward(self, x):
        n_samples = x.shape[0]
        x = self.conv1(x)
        x = self.conv5(x)
        X = x
        for block in self.blocks:
            x = block(x)
        x = self.norm3(x)
        x = self.convT(x)
        x = X + self.conv4(x)
        x = self.norm2(x)
        x = x.reshape(n_samples, 2*img_height*img_width)
        x = self.fc(x)
        return x

class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc = nn.Linear(encoded_dim, img_channels*img_height*img_width)
        self.act = nn.Sigmoid()
        self.conv5 = nn.Conv2d(2, 2, kernel_size=5, stride=1, padding=2)
        self.conv4 = nn.Conv2d(2, 2, kernel_size=4, stride=2, padding=1)
        self.convT = nn.ConvTranspose2d(2, 2, kernel_size=4, stride=2, padding=1)
        self.blocks = nn.ModuleList([WTL(num_heads=num_heads, qkv_bias=True) for _ in range(depth)])
        self.norm2 = nn.LayerNorm(img_width, eps=1e-6)
        self.norm3 = nn.LayerNorm(img_width, eps=1e-6)
        self.dense_layers = nn.Sequential(nn.Linear(encoded_dim, img_total))
        decoder = OrderedDict([
            ("conv5x5_bn", ConvBN(2, 2, 5)),
            ("relu", nn.LeakyReLU(negative_slope=0.3, inplace=True)),
            ("CRBlock1", CRBlock())
        ])
        self.decoder_feature = nn.Sequential(decoder)
    def forward(self, x):
        img = self.dense_layers(x)
        img = img.view(-1, img_channels, img_height, img_width)
        out = self.decoder_feature(img)
        x = self.conv5(img)
        for block in self.blocks:
            x = block((x + out))
        x = self.norm2(x)
        x = self.convT(x)
        x = self.conv4(x)
        for block in self.blocks:
            x = block((x + out))
        x = self.norm3(x)
        x = self.act(x)
        return x

# ===========================
# STEP 3: Train STNet Autoencoder
# ===========================
x_data = torch.tensor(all_csi, dtype=torch.float32).to(device)
encoder = Encoder().to(device)
decoder = Decoder().to(device)
opt_enc = Adam(encoder.parameters(), learning_rate, betas=(0.5, 0.999))
opt_dec = Adam(decoder.parameters(), learning_rate, betas=(0.5, 0.999))
loss_fn = nn.MSELoss()

def train_autoencoder(uncompressed_images):
    opt_enc.zero_grad()
    opt_dec.zero_grad()
    compressed_data = encoder(uncompressed_images)
    reconstructed_images = decoder(compressed_data)
    loss = loss_fn(uncompressed_images, reconstructed_images)
    loss.backward()
    opt_enc.step()
    opt_dec.step()
    return loss.item()

print("Training STNet autoencoder with encoded_dim=256 ...")
reps = int(len(x_data) / batch_size)
losses_auto = []
for epoch in range(epochs):
    idx = torch.randperm(x_data.size(0))
    for i in range(reps):
        batch = x_data[idx[i*batch_size:(i+1)*batch_size]]
        loss_auto = train_autoencoder(batch)
        if i % 10 == 0:
            print(f'epoch {epoch+1}/{epochs} batch: {i+1}/{reps} loss_auto: {loss_auto:.8f}')
        losses_auto.append(loss_auto)

plt.figure(figsize=(10, 4))
plt.title("STNet Autoencoder Loss During Training")
plt.plot(losses_auto, label="Train Loss")
plt.xlabel("iterations")
plt.ylabel("MSE Loss")
plt.legend()
plt.show()

# ===========================
# STEP 4: Compress and Save CSI Data
# ===========================
encoder.eval()
all_codes = []
with torch.no_grad():
    for i in tqdm(range(0, x_data.shape[0], batch_size)):
        batch = x_data[i:i+batch_size]
        code = encoder(batch)
        all_codes.append(code.cpu().numpy())
    all_codes = np.concatenate(all_codes, axis=0)
np.save(output_npy, all_codes)
print(f"\nSaved: {output_npy} (shape {all_codes.shape})")
# Out:
# Processing samples...
# 100%|██████████| 10000/10000 [00:14<00:00, 697.26it/s]
# All CSI array shape: (10000, 2, 32, 32)
# Training STNet autoencoder with encoded_dim=256 ...
# epoch 1/100 batch: 1/50 loss_auto: 0.61238545
# epoch 1/100 batch: 11/50 loss_auto: 0.50898415
# epoch 1/100 batch: 21/50 loss_auto: 0.47779632
# epoch 1/100 batch: 31/50 loss_auto: 0.47803375
# epoch 1/100 batch: 41/50 loss_auto: 0.45343974
# epoch 2/100 batch: 1/50 loss_auto: 0.45147309
# epoch 2/100 batch: 11/50 loss_auto: 0.44316989
# epoch 2/100 batch: 21/50 loss_auto: 0.43448263
# epoch 2/100 batch: 31/50 loss_auto: 0.43814176
# epoch 2/100 batch: 41/50 loss_auto: 0.42995781
# epoch 3/100 batch: 1/50 loss_auto: 0.43797016
# epoch 3/100 batch: 11/50 loss_auto: 0.42274496
# epoch 3/100 batch: 21/50 loss_auto: 0.42066246
# epoch 3/100 batch: 31/50 loss_auto: 0.41215357
# epoch 3/100 batch: 41/50 loss_auto: 0.40751815
# epoch 4/100 batch: 1/50 loss_auto: 0.39968818
# epoch 4/100 batch: 11/50 loss_auto: 0.41654953
# epoch 4/100 batch: 21/50 loss_auto: 0.40831307
# epoch 4/100 batch: 31/50 loss_auto: 0.40814352
# epoch 4/100 batch: 41/50 loss_auto: 0.39864683
# epoch 5/100 batch: 1/50 loss_auto: 0.39785483
# epoch 5/100 batch: 11/50 loss_auto: 0.40941963
# epoch 5/100 batch: 21/50 loss_auto: 0.40029216
# epoch 5/100 batch: 31/50 loss_auto: 0.40040144
# epoch 5/100 batch: 41/50 loss_auto: 0.38289511
# epoch 6/100 batch: 1/50 loss_auto: 0.38741690
# epoch 6/100 batch: 11/50 loss_auto: 0.39732996
# epoch 6/100 batch: 21/50 loss_auto: 0.38276961
# epoch 6/100 batch: 31/50 loss_auto: 0.38011706
# epoch 6/100 batch: 41/50 loss_auto: 0.38635284
# epoch 7/100 batch: 1/50 loss_auto: 0.37106353
# epoch 7/100 batch: 11/50 loss_auto: 0.38690832
# epoch 7/100 batch: 21/50 loss_auto: 0.36056030
# epoch 7/100 batch: 31/50 loss_auto: 0.37549266
# epoch 7/100 batch: 41/50 loss_auto: 0.36745507
# epoch 8/100 batch: 1/50 loss_auto: 0.36368659
# epoch 8/100 batch: 11/50 loss_auto: 0.36122370
# epoch 8/100 batch: 21/50 loss_auto: 0.34884262
# epoch 8/100 batch: 31/50 loss_auto: 0.37547097
# epoch 8/100 batch: 41/50 loss_auto: 0.36616936
# epoch 9/100 batch: 1/50 loss_auto: 0.36046794
# epoch 9/100 batch: 11/50 loss_auto: 0.36989543
# epoch 9/100 batch: 21/50 loss_auto: 0.35439172
# epoch 9/100 batch: 31/50 loss_auto: 0.35011891
# epoch 9/100 batch: 41/50 loss_auto: 0.34787431
# epoch 10/100 batch: 1/50 loss_auto: 0.35024071
# epoch 10/100 batch: 11/50 loss_auto: 0.34381941
# epoch 10/100 batch: 21/50 loss_auto: 0.35476810
# epoch 10/100 batch: 31/50 loss_auto: 0.33513770
# epoch 10/100 batch: 41/50 loss_auto: 0.33797637
# epoch 11/100 batch: 1/50 loss_auto: 0.34647673
# epoch 11/100 batch: 11/50 loss_auto: 0.34150124
# epoch 11/100 batch: 21/50 loss_auto: 0.34624499
# epoch 11/100 batch: 31/50 loss_auto: 0.32799262
# epoch 11/100 batch: 41/50 loss_auto: 0.32730579
# epoch 12/100 batch: 1/50 loss_auto: 0.34774795
# epoch 12/100 batch: 11/50 loss_auto: 0.33473444
# epoch 12/100 batch: 21/50 loss_auto: 0.32015815
# epoch 12/100 batch: 31/50 loss_auto: 0.33863157
# epoch 12/100 batch: 41/50 loss_auto: 0.31227180
# epoch 13/100 batch: 1/50 loss_auto: 0.32139179
# epoch 13/100 batch: 11/50 loss_auto: 0.31499892
# epoch 13/100 batch: 21/50 loss_auto: 0.32301822
# epoch 13/100 batch: 31/50 loss_auto: 0.31297028
# epoch 13/100 batch: 41/50 loss_auto: 0.32017988
# epoch 14/100 batch: 1/50 loss_auto: 0.32171661
# epoch 14/100 batch: 11/50 loss_auto: 0.30856645
# epoch 14/100 batch: 21/50 loss_auto: 0.32677504
# epoch 14/100 batch: 31/50 loss_auto: 0.31631061
# epoch 14/100 batch: 41/50 loss_auto: 0.31749526
# epoch 15/100 batch: 1/50 loss_auto: 0.30114460
# epoch 15/100 batch: 11/50 loss_auto: 0.31948662
# epoch 15/100 batch: 21/50 loss_auto: 0.31390291
# epoch 15/100 batch: 31/50 loss_auto: 0.29942915
# epoch 15/100 batch: 41/50 loss_auto: 0.31211704
# epoch 16/100 batch: 1/50 loss_auto: 0.29952389
# epoch 16/100 batch: 11/50 loss_auto: 0.31115848
# epoch 16/100 batch: 21/50 loss_auto: 0.30454773
# epoch 16/100 batch: 31/50 loss_auto: 0.31416014
# epoch 16/100 batch: 41/50 loss_auto: 0.30639923
# epoch 17/100 batch: 1/50 loss_auto: 0.30611938
# epoch 17/100 batch: 11/50 loss_auto: 0.30033076
# epoch 17/100 batch: 21/50 loss_auto: 0.30441645
# epoch 17/100 batch: 31/50 loss_auto: 0.30382413
# epoch 17/100 batch: 41/50 loss_auto: 0.30801934
# epoch 18/100 batch: 1/50 loss_auto: 0.30656356
# epoch 18/100 batch: 11/50 loss_auto: 0.29205373
# epoch 18/100 batch: 21/50 loss_auto: 0.28854063
# epoch 18/100 batch: 31/50 loss_auto: 0.29774016
# epoch 18/100 batch: 41/50 loss_auto: 0.27874672
# epoch 19/100 batch: 1/50 loss_auto: 0.30486175
# epoch 19/100 batch: 11/50 loss_auto: 0.28794011
# epoch 19/100 batch: 21/50 loss_auto: 0.29922023
# epoch 19/100 batch: 31/50 loss_auto: 0.31233150
# epoch 19/100 batch: 41/50 loss_auto: 0.28922373
# epoch 20/100 batch: 1/50 loss_auto: 0.28795531
# epoch 20/100 batch: 11/50 loss_auto: 0.28979096
# epoch 20/100 batch: 21/50 loss_auto: 0.29668960
# epoch 20/100 batch: 31/50 loss_auto: 0.29869398
# epoch 20/100 batch: 41/50 loss_auto: 0.27593735
# epoch 21/100 batch: 1/50 loss_auto: 0.29342636
# epoch 21/100 batch: 11/50 loss_auto: 0.27192381
# epoch 21/100 batch: 21/50 loss_auto: 0.28612700
# epoch 21/100 batch: 31/50 loss_auto: 0.29048392
# epoch 21/100 batch: 41/50 loss_auto: 0.27422008
# epoch 22/100 batch: 1/50 loss_auto: 0.28389812
# epoch 22/100 batch: 11/50 loss_auto: 0.28774017
# epoch 22/100 batch: 21/50 loss_auto: 0.27612525
# epoch 22/100 batch: 31/50 loss_auto: 0.28979412
# epoch 22/100 batch: 41/50 loss_auto: 0.28315482
# epoch 23/100 batch: 1/50 loss_auto: 0.27774489
# epoch 23/100 batch: 11/50 loss_auto: 0.27656275
# epoch 23/100 batch: 21/50 loss_auto: 0.27879348
# epoch 23/100 batch: 31/50 loss_auto: 0.27537692
# epoch 23/100 batch: 41/50 loss_auto: 0.28554597
# epoch 24/100 batch: 1/50 loss_auto: 0.27738917
# epoch 24/100 batch: 11/50 loss_auto: 0.28024289
# epoch 24/100 batch: 21/50 loss_auto: 0.27536768
# epoch 24/100 batch: 31/50 loss_auto: 0.29015985
# epoch 24/100 batch: 41/50 loss_auto: 0.27844256
# epoch 25/100 batch: 1/50 loss_auto: 0.26952034
# epoch 25/100 batch: 11/50 loss_auto: 0.27662402
# epoch 25/100 batch: 21/50 loss_auto: 0.27128455
# epoch 25/100 batch: 31/50 loss_auto: 0.27703473
# epoch 25/100 batch: 41/50 loss_auto: 0.26864815
# epoch 26/100 batch: 1/50 loss_auto: 0.28101942
# epoch 26/100 batch: 11/50 loss_auto: 0.28046870
# epoch 26/100 batch: 21/50 loss_auto: 0.27184206
# epoch 26/100 batch: 31/50 loss_auto: 0.27247295
# epoch 26/100 batch: 41/50 loss_auto: 0.28130764
# epoch 27/100 batch: 1/50 loss_auto: 0.28305098
# epoch 27/100 batch: 11/50 loss_auto: 0.26320785
# epoch 27/100 batch: 21/50 loss_auto: 0.26129597
# epoch 27/100 batch: 31/50 loss_auto: 0.27442324
# epoch 27/100 batch: 41/50 loss_auto: 0.26084194
# epoch 28/100 batch: 1/50 loss_auto: 0.26357540
# epoch 28/100 batch: 11/50 loss_auto: 0.26065937
# epoch 28/100 batch: 21/50 loss_auto: 0.26280379
# epoch 28/100 batch: 31/50 loss_auto: 0.27500132
# epoch 28/100 batch: 41/50 loss_auto: 0.26991221
# epoch 29/100 batch: 1/50 loss_auto: 0.27033353
# epoch 29/100 batch: 11/50 loss_auto: 0.26978701
# epoch 29/100 batch: 21/50 loss_auto: 0.26687002
# epoch 29/100 batch: 31/50 loss_auto: 0.26513484
# epoch 29/100 batch: 41/50 loss_auto: 0.25666174
# epoch 30/100 batch: 1/50 loss_auto: 0.27038157
# epoch 30/100 batch: 11/50 loss_auto: 0.26160055
# epoch 30/100 batch: 21/50 loss_auto: 0.24943744
# epoch 30/100 batch: 31/50 loss_auto: 0.26326734
# epoch 30/100 batch: 41/50 loss_auto: 0.25570425
# epoch 31/100 batch: 1/50 loss_auto: 0.26475912
# epoch 31/100 batch: 11/50 loss_auto: 0.25857475
# epoch 31/100 batch: 21/50 loss_auto: 0.26097086
# epoch 31/100 batch: 31/50 loss_auto: 0.26575205
# epoch 31/100 batch: 41/50 loss_auto: 0.26060608
# epoch 32/100 batch: 1/50 loss_auto: 0.25479215
# epoch 32/100 batch: 11/50 loss_auto: 0.26739064
# epoch 32/100 batch: 21/50 loss_auto: 0.25214615
# epoch 32/100 batch: 31/50 loss_auto: 0.26355734
# epoch 32/100 batch: 41/50 loss_auto: 0.25341144
# epoch 33/100 batch: 1/50 loss_auto: 0.25956422
# epoch 33/100 batch: 11/50 loss_auto: 0.25287139
# epoch 33/100 batch: 21/50 loss_auto: 0.26730719
# epoch 33/100 batch: 31/50 loss_auto: 0.25517946
# epoch 33/100 batch: 41/50 loss_auto: 0.25262332
# epoch 34/100 batch: 1/50 loss_auto: 0.25739571
# epoch 34/100 batch: 11/50 loss_auto: 0.26013163
# epoch 34/100 batch: 21/50 loss_auto: 0.25984988
# epoch 34/100 batch: 31/50 loss_auto: 0.24303035
# epoch 34/100 batch: 41/50 loss_auto: 0.26256794
# epoch 35/100 batch: 1/50 loss_auto: 0.25356665
# epoch 35/100 batch: 11/50 loss_auto: 0.24317259
# epoch 35/100 batch: 21/50 loss_auto: 0.25025886
# epoch 35/100 batch: 31/50 loss_auto: 0.24990229
# epoch 35/100 batch: 41/50 loss_auto: 0.24232559
# epoch 36/100 batch: 1/50 loss_auto: 0.24615890
# epoch 36/100 batch: 11/50 loss_auto: 0.25694197
# epoch 36/100 batch: 21/50 loss_auto: 0.25933570
# epoch 36/100 batch: 31/50 loss_auto: 0.24262021
# epoch 36/100 batch: 41/50 loss_auto: 0.24906567
# epoch 37/100 batch: 1/50 loss_auto: 0.25324976
# epoch 37/100 batch: 11/50 loss_auto: 0.24319762
# epoch 37/100 batch: 21/50 loss_auto: 0.24406707
# epoch 37/100 batch: 31/50 loss_auto: 0.25347012
# epoch 37/100 batch: 41/50 loss_auto: 0.25334772
# epoch 38/100 batch: 1/50 loss_auto: 0.24545673
# epoch 38/100 batch: 11/50 loss_auto: 0.25157711
# epoch 38/100 batch: 21/50 loss_auto: 0.24702621
# epoch 38/100 batch: 31/50 loss_auto: 0.24821281
# epoch 38/100 batch: 41/50 loss_auto: 0.24232873
# epoch 39/100 batch: 1/50 loss_auto: 0.25244617
# epoch 39/100 batch: 11/50 loss_auto: 0.24606106
# epoch 39/100 batch: 21/50 loss_auto: 0.24103165
# epoch 39/100 batch: 31/50 loss_auto: 0.24476536
# epoch 39/100 batch: 41/50 loss_auto: 0.24530761
# epoch 40/100 batch: 1/50 loss_auto: 0.25562128
# epoch 40/100 batch: 11/50 loss_auto: 0.25612006
# epoch 40/100 batch: 21/50 loss_auto: 0.23654212
# epoch 40/100 batch: 31/50 loss_auto: 0.24525829
# epoch 40/100 batch: 41/50 loss_auto: 0.24668674
# epoch 41/100 batch: 1/50 loss_auto: 0.24165630
# epoch 41/100 batch: 11/50 loss_auto: 0.24538912
# epoch 41/100 batch: 21/50 loss_auto: 0.24238086
# epoch 41/100 batch: 31/50 loss_auto: 0.24276070
# epoch 41/100 batch: 41/50 loss_auto: 0.23708576
# epoch 42/100 batch: 1/50 loss_auto: 0.24381059
# epoch 42/100 batch: 11/50 loss_auto: 0.23905100
# epoch 42/100 batch: 21/50 loss_auto: 0.24332950
# epoch 42/100 batch: 31/50 loss_auto: 0.24164966
# epoch 42/100 batch: 41/50 loss_auto: 0.24395522
# epoch 43/100 batch: 1/50 loss_auto: 0.24578932
# epoch 43/100 batch: 11/50 loss_auto: 0.24903117
# epoch 43/100 batch: 21/50 loss_auto: 0.23734479
# epoch 43/100 batch: 31/50 loss_auto: 0.24189681
# epoch 43/100 batch: 41/50 loss_auto: 0.23833868
# epoch 44/100 batch: 1/50 loss_auto: 0.24300250
# epoch 44/100 batch: 11/50 loss_auto: 0.24870086
# epoch 44/100 batch: 21/50 loss_auto: 0.24784818
# epoch 44/100 batch: 31/50 loss_auto: 0.25080892
# epoch 44/100 batch: 41/50 loss_auto: 0.23578347
# epoch 45/100 batch: 1/50 loss_auto: 0.24049978
# epoch 45/100 batch: 11/50 loss_auto: 0.24383301
# epoch 45/100 batch: 21/50 loss_auto: 0.24164245
# epoch 45/100 batch: 31/50 loss_auto: 0.22950780
# epoch 45/100 batch: 41/50 loss_auto: 0.23843625
# epoch 46/100 batch: 1/50 loss_auto: 0.22546920
# epoch 46/100 batch: 11/50 loss_auto: 0.23796992
# epoch 46/100 batch: 21/50 loss_auto: 0.24327902
# epoch 46/100 batch: 31/50 loss_auto: 0.24958666
# epoch 46/100 batch: 41/50 loss_auto: 0.23579997
# epoch 47/100 batch: 1/50 loss_auto: 0.22618765
# epoch 47/100 batch: 11/50 loss_auto: 0.24217322
# epoch 47/100 batch: 21/50 loss_auto: 0.24116203
# epoch 47/100 batch: 31/50 loss_auto: 0.24418552
# epoch 47/100 batch: 41/50 loss_auto: 0.23938815
# epoch 48/100 batch: 1/50 loss_auto: 0.23774144
# epoch 48/100 batch: 11/50 loss_auto: 0.24863884
# epoch 48/100 batch: 21/50 loss_auto: 0.24200496
# epoch 48/100 batch: 31/50 loss_auto: 0.23729984
# epoch 48/100 batch: 41/50 loss_auto: 0.23748340
# epoch 49/100 batch: 1/50 loss_auto: 0.24643230
# epoch 49/100 batch: 11/50 loss_auto: 0.23766173
# epoch 49/100 batch: 21/50 loss_auto: 0.23239978
# epoch 49/100 batch: 31/50 loss_auto: 0.23224449
# epoch 49/100 batch: 41/50 loss_auto: 0.24447238
# epoch 50/100 batch: 1/50 loss_auto: 0.24113922
# epoch 50/100 batch: 11/50 loss_auto: 0.24162641
# epoch 50/100 batch: 21/50 loss_auto: 0.24225631
# epoch 50/100 batch: 31/50 loss_auto: 0.22257651
# epoch 50/100 batch: 41/50 loss_auto: 0.24986206
# epoch 51/100 batch: 1/50 loss_auto: 0.22850661
# epoch 51/100 batch: 11/50 loss_auto: 0.25236157
# epoch 51/100 batch: 21/50 loss_auto: 0.23022591
# epoch 51/100 batch: 31/50 loss_auto: 0.23637183
# epoch 51/100 batch: 41/50 loss_auto: 0.23285294
# epoch 52/100 batch: 1/50 loss_auto: 0.23255512
# epoch 52/100 batch: 11/50 loss_auto: 0.24059536
# epoch 52/100 batch: 21/50 loss_auto: 0.24305698
# epoch 52/100 batch: 31/50 loss_auto: 0.23181513
# epoch 52/100 batch: 41/50 loss_auto: 0.23615736
# epoch 53/100 batch: 1/50 loss_auto: 0.23354477
# epoch 53/100 batch: 11/50 loss_auto: 0.23207618
# epoch 53/100 batch: 21/50 loss_auto: 0.22893508
# epoch 53/100 batch: 31/50 loss_auto: 0.24018897
# epoch 53/100 batch: 41/50 loss_auto: 0.23830070
# epoch 54/100 batch: 1/50 loss_auto: 0.23466380
# epoch 54/100 batch: 11/50 loss_auto: 0.23616795
# epoch 54/100 batch: 21/50 loss_auto: 0.23558974
# epoch 54/100 batch: 31/50 loss_auto: 0.23148552
# epoch 54/100 batch: 41/50 loss_auto: 0.23007877
# epoch 55/100 batch: 1/50 loss_auto: 0.23289485
# epoch 55/100 batch: 11/50 loss_auto: 0.23416002
# epoch 55/100 batch: 21/50 loss_auto: 0.24021201
# epoch 55/100 batch: 31/50 loss_auto: 0.22809909
# epoch 55/100 batch: 41/50 loss_auto: 0.23435120
# epoch 56/100 batch: 1/50 loss_auto: 0.23274422
# epoch 56/100 batch: 11/50 loss_auto: 0.23915203
# epoch 56/100 batch: 21/50 loss_auto: 0.23870471
# epoch 56/100 batch: 31/50 loss_auto: 0.23337354
# epoch 56/100 batch: 41/50 loss_auto: 0.23055667
# epoch 57/100 batch: 1/50 loss_auto: 0.22600433
# epoch 57/100 batch: 11/50 loss_auto: 0.23550624
# epoch 57/100 batch: 21/50 loss_auto: 0.23066524
# epoch 57/100 batch: 31/50 loss_auto: 0.22491294
# epoch 57/100 batch: 41/50 loss_auto: 0.23932293
# epoch 58/100 batch: 1/50 loss_auto: 0.22537139
# epoch 58/100 batch: 11/50 loss_auto: 0.23417629
# epoch 58/100 batch: 21/50 loss_auto: 0.23681699
# epoch 58/100 batch: 31/50 loss_auto: 0.22910810
# epoch 58/100 batch: 41/50 loss_auto: 0.22524685
# epoch 59/100 batch: 1/50 loss_auto: 0.22778015
# epoch 59/100 batch: 11/50 loss_auto: 0.23442565
# epoch 59/100 batch: 21/50 loss_auto: 0.22157665
# epoch 59/100 batch: 31/50 loss_auto: 0.23013006
# epoch 59/100 batch: 41/50 loss_auto: 0.22856635
# epoch 60/100 batch: 1/50 loss_auto: 0.22827728
# epoch 60/100 batch: 11/50 loss_auto: 0.22992590
# epoch 60/100 batch: 21/50 loss_auto: 0.23647468
# epoch 60/100 batch: 31/50 loss_auto: 0.24025463
# epoch 60/100 batch: 41/50 loss_auto: 0.22989075
# epoch 61/100 batch: 1/50 loss_auto: 0.22566120
# epoch 61/100 batch: 11/50 loss_auto: 0.22863269
# epoch 61/100 batch: 21/50 loss_auto: 0.23459946
# epoch 61/100 batch: 31/50 loss_auto: 0.23462112
# epoch 61/100 batch: 41/50 loss_auto: 0.23606236
# epoch 62/100 batch: 1/50 loss_auto: 0.21577777
# epoch 62/100 batch: 11/50 loss_auto: 0.22136123
# epoch 62/100 batch: 21/50 loss_auto: 0.22919832
# epoch 62/100 batch: 31/50 loss_auto: 0.23643959
# epoch 62/100 batch: 41/50 loss_auto: 0.23428789
# epoch 63/100 batch: 1/50 loss_auto: 0.22308768
# epoch 63/100 batch: 11/50 loss_auto: 0.22737184
# epoch 63/100 batch: 21/50 loss_auto: 0.22930227
# epoch 63/100 batch: 31/50 loss_auto: 0.22733106
# epoch 63/100 batch: 41/50 loss_auto: 0.22533014
# epoch 64/100 batch: 1/50 loss_auto: 0.22186309
# epoch 64/100 batch: 11/50 loss_auto: 0.23274574
# epoch 64/100 batch: 21/50 loss_auto: 0.22405627
# epoch 64/100 batch: 31/50 loss_auto: 0.22999705
# epoch 64/100 batch: 41/50 loss_auto: 0.23104370
# epoch 65/100 batch: 1/50 loss_auto: 0.23224041
# epoch 65/100 batch: 11/50 loss_auto: 0.23310380
# epoch 65/100 batch: 21/50 loss_auto: 0.22713141
# epoch 65/100 batch: 31/50 loss_auto: 0.21463756
# epoch 65/100 batch: 41/50 loss_auto: 0.23229125
# epoch 66/100 batch: 1/50 loss_auto: 0.22905098
# epoch 66/100 batch: 11/50 loss_auto: 0.22941913
# epoch 66/100 batch: 21/50 loss_auto: 0.22409236
# epoch 66/100 batch: 31/50 loss_auto: 0.22317369
# epoch 66/100 batch: 41/50 loss_auto: 0.22979282
# epoch 67/100 batch: 1/50 loss_auto: 0.21156067
# epoch 67/100 batch: 11/50 loss_auto: 0.22647844
# epoch 67/100 batch: 21/50 loss_auto: 0.22751167
# epoch 67/100 batch: 31/50 loss_auto: 0.20773810
# epoch 67/100 batch: 41/50 loss_auto: 0.23899367
# epoch 68/100 batch: 1/50 loss_auto: 0.20878389
# epoch 68/100 batch: 11/50 loss_auto: 0.22972128
# epoch 68/100 batch: 21/50 loss_auto: 0.22957374
# epoch 68/100 batch: 31/50 loss_auto: 0.22495739
# epoch 68/100 batch: 41/50 loss_auto: 0.22280715
# epoch 69/100 batch: 1/50 loss_auto: 0.21883991
# epoch 69/100 batch: 11/50 loss_auto: 0.23103806
# epoch 69/100 batch: 21/50 loss_auto: 0.22877660
# epoch 69/100 batch: 31/50 loss_auto: 0.23048091
# epoch 69/100 batch: 41/50 loss_auto: 0.22524089
# epoch 70/100 batch: 1/50 loss_auto: 0.23626514
# epoch 70/100 batch: 11/50 loss_auto: 0.21619567
# epoch 70/100 batch: 21/50 loss_auto: 0.22538795
# epoch 70/100 batch: 31/50 loss_auto: 0.22790432
# epoch 70/100 batch: 41/50 loss_auto: 0.21668845
# epoch 71/100 batch: 1/50 loss_auto: 0.23081645
# epoch 71/100 batch: 11/50 loss_auto: 0.23758535
# epoch 71/100 batch: 21/50 loss_auto: 0.22615413
# epoch 71/100 batch: 31/50 loss_auto: 0.21991281
# epoch 71/100 batch: 41/50 loss_auto: 0.23338151
# epoch 72/100 batch: 1/50 loss_auto: 0.21973565
# epoch 72/100 batch: 11/50 loss_auto: 0.22105804
# epoch 72/100 batch: 21/50 loss_auto: 0.23183486
# epoch 72/100 batch: 31/50 loss_auto: 0.22843295
# epoch 72/100 batch: 41/50 loss_auto: 0.22513023
# epoch 73/100 batch: 1/50 loss_auto: 0.22713934
# epoch 73/100 batch: 11/50 loss_auto: 0.21110372
# epoch 73/100 batch: 21/50 loss_auto: 0.22530216
# epoch 73/100 batch: 31/50 loss_auto: 0.23212120
# epoch 73/100 batch: 41/50 loss_auto: 0.23505658
# epoch 74/100 batch: 1/50 loss_auto: 0.22167741
# epoch 74/100 batch: 11/50 loss_auto: 0.23601644
# epoch 74/100 batch: 21/50 loss_auto: 0.21390343
# epoch 74/100 batch: 31/50 loss_auto: 0.22154737
# epoch 74/100 batch: 41/50 loss_auto: 0.21076104
# epoch 75/100 batch: 1/50 loss_auto: 0.22770120
# epoch 75/100 batch: 11/50 loss_auto: 0.21126251
# epoch 75/100 batch: 21/50 loss_auto: 0.22059172
# epoch 75/100 batch: 31/50 loss_auto: 0.22305477
# epoch 75/100 batch: 41/50 loss_auto: 0.22460136
# epoch 76/100 batch: 1/50 loss_auto: 0.21871376
# epoch 76/100 batch: 11/50 loss_auto: 0.22628500
# epoch 76/100 batch: 21/50 loss_auto: 0.21337059
# epoch 76/100 batch: 31/50 loss_auto: 0.23431900
# epoch 76/100 batch: 41/50 loss_auto: 0.21287730
# epoch 77/100 batch: 1/50 loss_auto: 0.22937435
# epoch 77/100 batch: 11/50 loss_auto: 0.22643097
# epoch 77/100 batch: 21/50 loss_auto: 0.22514950
# epoch 77/100 batch: 31/50 loss_auto: 0.22963966
# epoch 77/100 batch: 41/50 loss_auto: 0.22347079
# epoch 78/100 batch: 1/50 loss_auto: 0.22549823
# epoch 78/100 batch: 11/50 loss_auto: 0.22691120
# epoch 78/100 batch: 21/50 loss_auto: 0.21719173
# epoch 78/100 batch: 31/50 loss_auto: 0.22339591
# epoch 78/100 batch: 41/50 loss_auto: 0.20609972
# epoch 79/100 batch: 1/50 loss_auto: 0.22761337
# epoch 79/100 batch: 11/50 loss_auto: 0.21804662
# epoch 79/100 batch: 21/50 loss_auto: 0.21477462
# epoch 79/100 batch: 31/50 loss_auto: 0.22644256
# epoch 79/100 batch: 41/50 loss_auto: 0.22136894
# epoch 80/100 batch: 1/50 loss_auto: 0.22379787
# epoch 80/100 batch: 11/50 loss_auto: 0.21911411
# epoch 80/100 batch: 21/50 loss_auto: 0.22358944
# epoch 80/100 batch: 31/50 loss_auto: 0.21738464
# epoch 80/100 batch: 41/50 loss_auto: 0.22471778
# epoch 81/100 batch: 1/50 loss_auto: 0.21245772
# epoch 81/100 batch: 11/50 loss_auto: 0.21883433
# epoch 81/100 batch: 21/50 loss_auto: 0.22781040
# epoch 81/100 batch: 31/50 loss_auto: 0.22688603
# epoch 81/100 batch: 41/50 loss_auto: 0.22108102
# epoch 82/100 batch: 1/50 loss_auto: 0.22700146
# epoch 82/100 batch: 11/50 loss_auto: 0.22254516
# epoch 82/100 batch: 21/50 loss_auto: 0.21613976
# epoch 82/100 batch: 31/50 loss_auto: 0.23237671
# epoch 82/100 batch: 41/50 loss_auto: 0.22739112
# epoch 83/100 batch: 1/50 loss_auto: 0.22803791
# epoch 83/100 batch: 11/50 loss_auto: 0.22658259
# epoch 83/100 batch: 21/50 loss_auto: 0.22366148
# epoch 83/100 batch: 31/50 loss_auto: 0.21785268
# epoch 83/100 batch: 41/50 loss_auto: 0.21857698
# epoch 84/100 batch: 1/50 loss_auto: 0.21732686
# epoch 84/100 batch: 11/50 loss_auto: 0.21929859
# epoch 84/100 batch: 21/50 loss_auto: 0.22326732
# epoch 84/100 batch: 31/50 loss_auto: 0.21801788
# epoch 84/100 batch: 41/50 loss_auto: 0.22110061
# epoch 85/100 batch: 1/50 loss_auto: 0.22135633
# epoch 85/100 batch: 11/50 loss_auto: 0.20803946
# epoch 85/100 batch: 21/50 loss_auto: 0.22100948
# epoch 85/100 batch: 31/50 loss_auto: 0.22679324
# epoch 85/100 batch: 41/50 loss_auto: 0.22430325
# epoch 86/100 batch: 1/50 loss_auto: 0.23038955
# epoch 86/100 batch: 11/50 loss_auto: 0.21875599
# epoch 86/100 batch: 21/50 loss_auto: 0.21496929
# epoch 86/100 batch: 31/50 loss_auto: 0.22051397
# epoch 86/100 batch: 41/50 loss_auto: 0.22886604
# epoch 87/100 batch: 1/50 loss_auto: 0.22151378
# epoch 87/100 batch: 11/50 loss_auto: 0.21510638
# epoch 87/100 batch: 21/50 loss_auto: 0.23243181
# epoch 87/100 batch: 31/50 loss_auto: 0.21026397
# epoch 87/100 batch: 41/50 loss_auto: 0.20826919
# epoch 88/100 batch: 1/50 loss_auto: 0.20649669
# epoch 88/100 batch: 11/50 loss_auto: 0.21638681
# epoch 88/100 batch: 21/50 loss_auto: 0.21247642
# epoch 88/100 batch: 31/50 loss_auto: 0.22516274
# epoch 88/100 batch: 41/50 loss_auto: 0.21518265
# epoch 89/100 batch: 1/50 loss_auto: 0.21722850
# epoch 89/100 batch: 11/50 loss_auto: 0.21914825
# epoch 89/100 batch: 21/50 loss_auto: 0.22512542
# epoch 89/100 batch: 31/50 loss_auto: 0.22629727
# epoch 89/100 batch: 41/50 loss_auto: 0.22231609
# epoch 90/100 batch: 1/50 loss_auto: 0.20809150
# epoch 90/100 batch: 11/50 loss_auto: 0.21032378
# epoch 90/100 batch: 21/50 loss_auto: 0.21452320
# epoch 90/100 batch: 31/50 loss_auto: 0.22163206
# epoch 90/100 batch: 41/50 loss_auto: 0.21840236
# epoch 91/100 batch: 1/50 loss_auto: 0.22193870
# epoch 91/100 batch: 11/50 loss_auto: 0.22636230
# epoch 91/100 batch: 21/50 loss_auto: 0.22085901
# epoch 91/100 batch: 31/50 loss_auto: 0.21708229
# epoch 91/100 batch: 41/50 loss_auto: 0.22053432
# epoch 92/100 batch: 1/50 loss_auto: 0.22546370
# epoch 92/100 batch: 11/50 loss_auto: 0.22072665
# epoch 92/100 batch: 21/50 loss_auto: 0.21959877
# epoch 92/100 batch: 31/50 loss_auto: 0.22162697
# epoch 92/100 batch: 41/50 loss_auto: 0.21085382
# epoch 93/100 batch: 1/50 loss_auto: 0.22587903
# epoch 93/100 batch: 11/50 loss_auto: 0.21179447
# epoch 93/100 batch: 21/50 loss_auto: 0.21530741
# epoch 93/100 batch: 31/50 loss_auto: 0.22586913
# epoch 93/100 batch: 41/50 loss_auto: 0.21339944
# epoch 94/100 batch: 1/50 loss_auto: 0.23095489
# epoch 94/100 batch: 11/50 loss_auto: 0.21585575
# epoch 94/100 batch: 21/50 loss_auto: 0.22851120
# epoch 94/100 batch: 31/50 loss_auto: 0.21381518
# epoch 94/100 batch: 41/50 loss_auto: 0.22031982
# epoch 95/100 batch: 1/50 loss_auto: 0.22229046
# epoch 95/100 batch: 11/50 loss_auto: 0.22853903
# epoch 95/100 batch: 21/50 loss_auto: 0.21828228
# epoch 95/100 batch: 31/50 loss_auto: 0.21878143
# epoch 95/100 batch: 41/50 loss_auto: 0.21572487
# epoch 96/100 batch: 1/50 loss_auto: 0.22182827
# epoch 96/100 batch: 11/50 loss_auto: 0.21517934
# epoch 96/100 batch: 21/50 loss_auto: 0.22225063
# epoch 96/100 batch: 31/50 loss_auto: 0.22533743
# epoch 96/100 batch: 41/50 loss_auto: 0.22907887
# epoch 97/100 batch: 1/50 loss_auto: 0.21535820
# epoch 97/100 batch: 11/50 loss_auto: 0.20240992
# epoch 97/100 batch: 21/50 loss_auto: 0.22501861
# epoch 97/100 batch: 31/50 loss_auto: 0.21409893
# epoch 97/100 batch: 41/50 loss_auto: 0.21308552
# epoch 98/100 batch: 1/50 loss_auto: 0.21837139
# epoch 98/100 batch: 11/50 loss_auto: 0.22673552
# epoch 98/100 batch: 21/50 loss_auto: 0.21931097
# epoch 98/100 batch: 31/50 loss_auto: 0.21696708
# epoch 98/100 batch: 41/50 loss_auto: 0.22932094
# epoch 99/100 batch: 1/50 loss_auto: 0.22664574
# epoch 99/100 batch: 11/50 loss_auto: 0.21519446
# epoch 99/100 batch: 21/50 loss_auto: 0.20948711
# epoch 99/100 batch: 31/50 loss_auto: 0.21593526
# epoch 99/100 batch: 41/50 loss_auto: 0.21963555
# epoch 100/100 batch: 1/50 loss_auto: 0.22268993
# epoch 100/100 batch: 11/50 loss_auto: 0.22296886
# epoch 100/100 batch: 21/50 loss_auto: 0.21686833
# epoch 100/100 batch: 31/50 loss_auto: 0.22278354
# epoch 100/100 batch: 41/50 loss_auto: 0.21414241
# 100%|██████████| 50/50 [00:00<00:00, 98.62it/s]
# Saved: CSI_Comp_256_paper.npy (shape (10000, 256))

# %%
torch.save(decoder.state_dict(), 'stnet_paperdecoder_256.pt')
